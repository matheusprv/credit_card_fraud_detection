# %%
from prepare_dataset import MyDataset
df = MyDataset("../data/treino.csv")

# %%
df.df
# Out:
#         gender  city  state       lat      long  city_pop  job  trans_date  \
# 0            1   114      4  0.373000 -0.651000  0.038657   43         209
# 1            0   126      4  0.378667 -0.653500  0.055619   95         354
# 2            1    91      4  0.385444 -0.656389  0.060768  170         209
# 3            0    24     26  0.435222 -0.665444  0.020606   71          29
# 4            1   142     27  0.479667 -0.430889  0.159376  144         173
# ...        ...   ...    ...       ...       ...       ...  ...         ...
# 144347       0   115      9  0.460333 -0.505833  0.010226  157         228
# 144348       0    90      7  0.309556 -0.453167  0.012366   39         135
# 144349       1    47      9  0.451444 -0.521167  0.000194  118         111
# 144350       1    63     37  0.486222 -0.492278  0.020254    4         194
# 144351       0    87     15  0.359111 -0.521611  0.004068   69          34
#
# ...

# %%
df.df["is_fraud"].value_counts().to_dict()
# Out:
# {0.0: 142666, 1.0: 1528}
